# %%
import pandas as pd

df = pd.read_excel('data/dados_cerveja_nota.xlsx')

df
# Out:
#     id  cerveja   nota
# 0    1        1   0.75
# 1    2        1   3.00
# 2    3        2   1.75
# 3    4        3   1.75
# 4    5        4   4.20
# 5    6        4   6.50
# 6    7        5   2.90
# 7    8        6   6.20
# 8    9        6   7.00
# 9   10        7   6.20
# 10  11        8   8.50
# 11  12        8  10.00
# 12  13        9   8.60
# 13  14        9   9.90
# 14  15        9  10.00

# %%
from sklearn import linear_model

X = df[['cerveja']]
y = df[['nota']]

model = linear_model.LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
a, b = model.intercept_[0], model.coef_[0][0]

print(a, b)
# Out:
# 0.151612903225808 1.0362903225806448

# %%
predict = model.predict(X.drop_duplicates())

import matplotlib.pyplot as plt

plt.plot(X['cerveja'], y, 'o')
plt.grid(True)
plt.title("Relação Cerveja vs Nota")
plt.xlabel("Cerveja")
plt.ylabel("Nota")

plt.plot(X.drop_duplicates()['cerveja'], predict)

plt.legend(['Observado', f'y= {a:.3} + {b:.3}x'])

# %%
from sklearn import tree

tree = tree.DecisionTreeRegressor(random_state=43, 
                                  max_depth=2)

tree.fit(X, y)
predict_tree = tree.predict(X.drop_duplicates())

plt.plot(X['cerveja'], y, 'o')
plt.grid(True)
plt.title("Relação Cerveja vs Nota")
plt.xlabel("Cerveja")
plt.ylabel("Nota")

plt.plot(X.drop_duplicates()['cerveja'], predict)
plt.plot(X.drop_duplicates()['cerveja'], predict_tree)

plt.legend(['Observado', 
            f'y= {a:.3} + {b:.3}x',
            'Decison Tree'])
