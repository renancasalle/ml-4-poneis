# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/1YQBQ3bu1TCmgrRch1gzW5O4Jgc8huzUSr7VUkxg0KIw/export?gid=283387421&format=csv"

df = pd.read_csv(url)

df
# Out:
#     Carimbo de data/hora Como conheceu o Téo Me Why?  \
# 0    12/06/2025 10:59:27                    LinkedIn
# 1    12/06/2025 10:59:34                      Twitch
# 2    12/06/2025 10:59:36                     YouTube
# 3    12/06/2025 10:59:37                     YouTube
# 4    12/06/2025 10:59:41                      Twitch
# ..                   ...                         ...
# 177  13/06/2025 11:23:48                      Amigos
# 178  13/06/2025 11:41:05                      Twitch
# 179  13/06/2025 20:45:50                 Twitter / X
# 180  14/06/2025 18:09:20                    LinkedIn
# 181  14/06/2025 18:39:45                     YouTube
#
#     Quantos cursos acompanhou do Téo Me Why? Curte games? Curte futebol?  \
# 0                                          0          Sim            Não
# 1                                 Mais que 3          Sim            Sim
# 2                                 Mais que 3          Sim            Sim
# 3                                 Mais que 3          Sim            Sim
# 4                                          2          Sim            Sim
# ..                                       ...          ...            ...
# 177                                        2          Sim            Sim
# 178                               Mais que 3          Sim            Sim
# 179                                        1          Sim            Sim
# 180                                        1          Sim            Não
# 181                                        1          Sim            Não
#
#     Curte livros? Curte jogos de tabuleiro? Curte jogos de fórmula 1?  \
# 0             Sim                       Sim                       Sim
# 1             Sim                       Não                       Não
# 2             Sim                       Sim                       Sim
# 3             Sim                       Sim                       Sim
# 4             Sim                       Sim                       Não
# ..            ...                       ...                       ...
# 177           Sim                       Não                       Sim
# 178           Sim                       Sim                       Sim
# 179           Sim                       Sim                       Não
# 180           Sim                       Não                       Não
# 181           Sim                       Sim                       Não
#
#     Curte jogos de MMA?  Idade Estado que mora atualmente Área de Formação  \
# 0                   Não     34                         MG           Exatas
# 1                   Sim     26                         MG           Exatas
# 2                   Sim     39                         SC           Exatas
# 3                   Não     27                         SP           Exatas
# 4                   Não     29                         CE           Exatas
# ..                  ...    ...                        ...              ...
# 177                 Não     33                         SC          Humanas
# 178                 Sim     32                         PR       Biológicas
# 179                 Não     39                         SP           Exatas
# 180                 Não     25                         SP           Exatas
# 181                 Não     43                         MG           Exatas
#
#     Tempo que atua na área de dados Posição da cadeira (senioridade)  \
# 0                    Mais de 4 anos                           Sênior
# 1                          Não atuo                        Iniciante
# 2                 De 1 ano a 2 anos                           Júnior
# 3                    Mais de 4 anos                            Pleno
# 4                 De 1 ano a 2 anos                            Pleno
# ..                              ...                              ...
# 177              de 2 anos a 4 anos                           Júnior
# 178                  Mais de 4 anos                           Sênior
# 179                        Não atuo                        Iniciante
# 180               De 1 ano a 2 anos                            Pleno
# 181                        Não atuo                     Especialista
#
#     Você se considera uma pessoa feliz?
# 0                                   Sim
# 1                                   Sim
# 2                                   Sim
# 3                                   Sim
# 4                                   Sim
# ..                                  ...
# 177                                 Sim
# 178                                 Sim
# 179                                 Não
# 180                                 Não
# 181                                 Sim
#
# [182 rows x 15 columns]

# %%
df = df.replace({"Sim": 1, "Não": 0})

num_vars = [
    'Curte games?',
    'Curte futebol?',
    'Curte livros?',
    'Curte jogos de tabuleiro?',
    'Curte jogos de fórmula 1?',
    'Curte jogos de MMA?',
    'Idade',
]

dummy_vars = [
    "Como conheceu o Téo Me Why?",	
    "Quantos cursos acompanhou do Téo Me Why?",
    "Estado que mora atualmente",
    "Área de Formação",	
    "Tempo que atua na área de dados",	
    "Posição da cadeira (senioridade)"
]

df_analise = pd.get_dummies(df[dummy_vars]).astype(int)
df_analise[num_vars] = df[num_vars].copy()
df_analise['pessoa_feliz']=df['Você se considera uma pessoa feliz?'].copy()
# Out:
# C:\Users\Renan Casalle\AppData\Local\Temp\ipykernel_36108\4137482249.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({"Sim": 1, "Não": 0})

# %%
from sklearn import tree

X = df_analise.drop(columns=['pessoa_feliz'])
y = df_analise['pessoa_feliz']

SEED = 42

tree_model = tree.DecisionTreeClassifier(random_state=SEED,
                            min_samples_leaf=5,
                            )

tree_model.fit(X, y)
# Out:
# DecisionTreeClassifier(min_samples_leaf=5, random_state=42)

# %%
tree_predict = tree_model.predict(X)

df_predict = df_analise[['pessoa_feliz']]
df_predict['predict_tree'] = tree_predict
df_predict
# Out:
# C:\Users\Renan Casalle\AppData\Local\Temp\ipykernel_36108\4069428185.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['predict_tree'] = tree_predict
#      pessoa_feliz  predict_tree
# 0               1             1
# 1               1             1
# 2               1             1
# 3               1             1
# 4               1             1
# ..            ...           ...
# 177             1             1
# 178             1             1
# 179             0             0
# 180             0             0
# 181             1             1
#
# [182 rows x 2 columns]

# %%
# Acurácia do modelo

print((df_predict['pessoa_feliz'] == df_predict['predict_tree']).mean())

# Matriz de confusão

pd.crosstab(df_predict['pessoa_feliz'], df_predict['predict_tree'])
# Out:
# 0.8626373626373627
# predict_tree   0    1
# pessoa_feliz
# 0             16   19
# 1              6  141
